# %%
import pandas as pd

# %%
tn_df = pd.read_csv('Data/tn.movie_budgets.csv.gz')
tn_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
tn_df.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
# Dropped the release date as itg is not important to compare with production budget, domestic and worldwide gross.

updated_tn_df = tn_df.drop(columns=['release_date'])
updated_tn_df
# Out:
#       id                                        movie production_budget  \
# 0      1                                       Avatar      $425,000,000
# 1      2  Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2      3                                 Dark Phoenix      $350,000,000
# 3      4                      Avengers: Age of Ultron      $330,600,000
# 4      5            Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...   ..                                          ...               ...
# 5777  78                                       Red 11            $7,000
# 5778  79                                    Following            $6,000
# 5779  80                Return to the Land of Wonders            $5,000
# 5780  81                         A Plague So Pleasant            $1,400
# 5781  82                            My Date With Drew            $1,100
#
#      domestic_gross worldwide_gross
# 0      $760,507,625  $2,776,345,279
# 1      $241,063,875  $1,045,663,875
# 2       $42,762,350    $149,762,350
# 3      $459,005,868  $1,403,013,963
# 4      $620,181,382  $1,316,721,747
# ...             ...             ...
# 5777             $0              $0
# 5778        $48,482        $240,495
# 5779         $1,338          $1,338
# 5780             $0              $0
# 5781       $181,041        $181,041
#
# [5782 rows x 5 columns]

# %%
updated_tn_df.head(20)
# Out:
#     id                                        movie production_budget  \
# 0    1                                       Avatar      $425,000,000
# 1    2  Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2    3                                 Dark Phoenix      $350,000,000
# 3    4                      Avengers: Age of Ultron      $330,600,000
# 4    5            Star Wars Ep. VIII: The Last Jedi      $317,000,000
# 5    6         Star Wars Ep. VII: The Force Awakens      $306,000,000
# 6    7                       Avengers: Infinity War      $300,000,000
# 7    8   Pirates of the Caribbean: At Worldâs End      $300,000,000
# 8    9                               Justice League      $300,000,000
# 9   10                                      Spectre      $300,000,000
# 10  11                        The Dark Knight Rises      $275,000,000
# 11  12                      Solo: A Star Wars Story      $275,000,000
# 12  13                              The Lone Ranger      $275,000,000
# 13  14                                  John Carter      $275,000,000
# 14  15                                      Tangled      $260,000,000
# 15  16                                 Spider-Man 3      $258,000,000
# 16  17                   Captain America: Civil War      $250,000,000
# 17  18           Batman v Superman: Dawn of Justice      $250,000,000
# 18  19            The Hobbit: An Unexpected Journey      $250,000,000
# 19  20       Harry Potter and the Half-Blood Prince      $250,000,000
#
#    domestic_gross worldwide_gross
# 0    $760,507,625  $2,776,345,279
# 1    $241,063,875  $1,045,663,875
# 2     $42,762,350    $149,762,350
# 3    $459,005,868  $1,403,013,963
# 4    $620,181,382  $1,316,721,747
# 5    $936,662,225  $2,053,311,220
# 6    $678,815,482  $2,048,134,200
# 7    $309,420,425    $963,420,425
# 8    $229,024,295    $655,945,209
# 9    $200,074,175    $879,620,923
# 10   $448,139,099  $1,084,439,099
# 11   $213,767,512    $393,151,347
# 12    $89,302,115    $260,002,115
# 13    $73,058,679    $282,778,100
# 14   $200,821,936    $586,477,240
# 15   $336,530,303    $894,860,230
# 16   $408,084,349  $1,140,069,413
# 17   $330,360,194    $867,500,281
# 18   $303,003,568  $1,017,003,568
# 19   $302,089,278    $935,213,767

# %%
updated_tn_df['production_budget'].value_counts()
# Out:
# $20,000,000    231
# $10,000,000    212
# $30,000,000    177
# $15,000,000    173
# $25,000,000    171
#               ...
# $8,250,000       1
# $7,800,000       1
# $13,400,000      1
# $10,400,000      1
# $609,000         1
# Name: production_budget, Length: 509, dtype: int64

# %%
updated_tn_df['domestic_gross'].value_counts()
# Out:
# $0              548
# $8,000,000        9
# $2,000,000        7
# $7,000,000        7
# $10,000,000       6
#                ...
# $952,432          1
# $70,052,444       1
# $101,117,573      1
# $3,347,647        1
# $28,426,747       1
# Name: domestic_gross, Length: 5164, dtype: int64

# %%
updated_tn_df['worldwide_gross'].value_counts()
# Out:
# $0              367
# $8,000,000        9
# $2,000,000        6
# $7,000,000        6
# $9,000,000        4
#                ...
# $1,945,420        1
# $9,307,166        1
# $731,463,377      1
# $3,347,647        1
# $15,298,355       1
# Name: worldwide_gross, Length: 5356, dtype: int64

# %%
updated_tn_df
# Out:
#       id                                        movie production_budget  \
# 0      1                                       Avatar      $425,000,000
# 1      2  Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2      3                                 Dark Phoenix      $350,000,000
# 3      4                      Avengers: Age of Ultron      $330,600,000
# 4      5            Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...   ..                                          ...               ...
# 5777  78                                       Red 11            $7,000
# 5778  79                                    Following            $6,000
# 5779  80                Return to the Land of Wonders            $5,000
# 5780  81                         A Plague So Pleasant            $1,400
# 5781  82                            My Date With Drew            $1,100
#
#      domestic_gross worldwide_gross
# 0      $760,507,625  $2,776,345,279
# 1      $241,063,875  $1,045,663,875
# 2       $42,762,350    $149,762,350
# 3      $459,005,868  $1,403,013,963
# 4      $620,181,382  $1,316,721,747
# ...             ...             ...
# 5777             $0              $0
# 5778        $48,482        $240,495
# 5779         $1,338          $1,338
# 5780             $0              $0
# 5781       $181,041        $181,041
#
# [5782 rows x 5 columns]

# %%
updated_tn_df['production_budget'].str.replace('$', '').str.replace(',', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-2e5e73f5f0b9> in <module>
# ----> 1 updated_tn_df['production_budget'].str.replace('$', '').str.replace(',', '').astype(int)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    2098
#    2099     def __init__(self, data):
# -> 2100         self._inferred_dtype = self._validate(data)
#    2101         self._is_categorical = is_categorical_dtype(data.dtype)
#    2102         self._is_string = data.dtype.name == "string"
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\strings.py in _validate(data)
#    2155
#    2156         if inferred_dtype not in allowed_types:
# -> 2157             raise AttributeError("Can only use .str accessor with string values!")
#    2158         return inferred_dtype
#    2159
#
# AttributeError: Can only use .str accessor with string values!

# %%
updated_tn_df['production_budget'] = updated_tn_df['production_budget'].str.replace('$', '').str.replace(',', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-42081ed0ada0> in <module>
# ----> 1 updated_tn_df['production_budget'] = updated_tn_df['production_budget'].str.replace('$', '').str.replace(',', '').astype(int)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    2098
#    2099     def __init__(self, data):
# -> 2100         self._inferred_dtype = self._validate(data)
#    2101         self._is_categorical = is_categorical_dtype(data.dtype)
#    2102         self._is_string = data.dtype.name == "string"
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\strings.py in _validate(data)
#    2155
#    2156         if inferred_dtype not in allowed_types:
# -> 2157             raise AttributeError("Can only use .str accessor with string values!")
#    2158         return inferred_dtype
#    2159
#
# AttributeError: Can only use .str accessor with string values!

# %%
updated_tn_df
# Out:
#       id                                        movie  production_budget  \
# 0      1                                       Avatar          425000000
# 1      2  Pirates of the Caribbean: On Stranger Tides          410600000
# 2      3                                 Dark Phoenix          350000000
# 3      4                      Avengers: Age of Ultron          330600000
# 4      5            Star Wars Ep. VIII: The Last Jedi          317000000
# ...   ..                                          ...                ...
# 5777  78                                       Red 11               7000
# 5778  79                                    Following               6000
# 5779  80                Return to the Land of Wonders               5000
# 5780  81                         A Plague So Pleasant               1400
# 5781  82                            My Date With Drew               1100
#
#      domestic_gross worldwide_gross
# 0      $760,507,625  $2,776,345,279
# 1      $241,063,875  $1,045,663,875
# 2       $42,762,350    $149,762,350
# 3      $459,005,868  $1,403,013,963
# 4      $620,181,382  $1,316,721,747
# ...             ...             ...
# 5777             $0              $0
# 5778        $48,482        $240,495
# 5779         $1,338          $1,338
# 5780             $0              $0
# 5781       $181,041        $181,041
#
# [5782 rows x 5 columns]

# %%
updated_tn_df['domestic_gross'].str.replace('$', '').str.replace(',', '').astype(int)
# Out:
# 0       760507625
# 1       241063875
# 2        42762350
# 3       459005868
# 4       620181382
#           ...
# 5777            0
# 5778        48482
# 5779         1338
# 5780            0
# 5781       181041
# Name: domestic_gross, Length: 5782, dtype: int32

# %%
updated_tn_df['domestic_gross'] = updated_tn_df['domestic_gross'].str.replace('$', '').str.replace(',', '').astype(int)

# %%
updated_tn_df
# Out:
#       id                                        movie  production_budget  \
# 0      1                                       Avatar          425000000
# 1      2  Pirates of the Caribbean: On Stranger Tides          410600000
# 2      3                                 Dark Phoenix          350000000
# 3      4                      Avengers: Age of Ultron          330600000
# 4      5            Star Wars Ep. VIII: The Last Jedi          317000000
# ...   ..                                          ...                ...
# 5777  78                                       Red 11               7000
# 5778  79                                    Following               6000
# 5779  80                Return to the Land of Wonders               5000
# 5780  81                         A Plague So Pleasant               1400
# 5781  82                            My Date With Drew               1100
#
#       domestic_gross worldwide_gross
# 0          760507625  $2,776,345,279
# 1          241063875  $1,045,663,875
# 2           42762350    $149,762,350
# 3          459005868  $1,403,013,963
# 4          620181382  $1,316,721,747
# ...              ...             ...
# 5777               0              $0
# 5778           48482        $240,495
# 5779            1338          $1,338
# 5780               0              $0
# 5781          181041        $181,041
#
# [5782 rows x 5 columns]

# %%
updated_tn_df['worldwide_gross'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# 0       2.776345e+09
# 1       1.045664e+09
# 2       1.497624e+08
# 3       1.403014e+09
# 4       1.316722e+09
#             ...
# 5777    0.000000e+00
# 5778    2.404950e+05
# 5779    1.338000e+03
# 5780    0.000000e+00
# 5781    1.810410e+05
# Name: worldwide_gross, Length: 5782, dtype: float64

# %%
updated_tn_df['worldwide_gross'] = updated_tn_df['worldwide_gross'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
updated_tn_df
# Out:
#       id                                        movie  production_budget  \
# 0      1                                       Avatar          425000000
# 1      2  Pirates of the Caribbean: On Stranger Tides          410600000
# 2      3                                 Dark Phoenix          350000000
# 3      4                      Avengers: Age of Ultron          330600000
# 4      5            Star Wars Ep. VIII: The Last Jedi          317000000
# ...   ..                                          ...                ...
# 5777  78                                       Red 11               7000
# 5778  79                                    Following               6000
# 5779  80                Return to the Land of Wonders               5000
# 5780  81                         A Plague So Pleasant               1400
# 5781  82                            My Date With Drew               1100
#
#       domestic_gross  worldwide_gross
# 0          760507625     2.776345e+09
# 1          241063875     1.045664e+09
# 2           42762350     1.497624e+08
# 3          459005868     1.403014e+09
# 4          620181382     1.316722e+09
# ...              ...              ...
# 5777               0     0.000000e+00
# 5778           48482     2.404950e+05
# 5779            1338     1.338000e+03
# 5780               0     0.000000e+00
# 5781          181041     1.810410e+05
#
# [5782 rows x 5 columns]

# %%
updated_tn_df.sort_values('domestic_gross', ascending=False)
# Out:
#       id                                       movie  production_budget  \
# 5      6        Star Wars Ep. VII: The Force Awakens          306000000
# 0      1                                      Avatar          425000000
# 41    42                               Black Panther          200000000
# 6      7                      Avengers: Infinity War          300000000
# 42    43                                     Titanic          200000000
# ...   ..                                         ...                ...
# 2709  10                                   The Touch           20000000
# 2708   9  Three Kingdoms: Resurrection of the Dragon           20000000
# 2707   8                                    Zambezia           20000000
# 2706   7                                     Admiral           20000000
# 5317  18                                 A Fine Step            1000000
#
#       domestic_gross  worldwide_gross
# 5          936662225     2.053311e+09
# 0          760507625     2.776345e+09
# 41         700059566     1.348258e+09
# 6          678815482     2.048134e+09
# 42         659363944     2.208208e+09
# ...              ...              ...
# 2709               0     5.918742e+06
# 2708               0     2.213959e+07
# 2707               0     3.445434e+07
# 2706               0     3.858505e+07
# 5317               0     0.000000e+00
#
# [5782 rows x 5 columns]

# %%
updated_tn_df.sort_values('worldwide_gross', ascending=False)
# Out:
#       id                                 movie  production_budget  \
# 0      1                                Avatar          425000000
# 42    43                               Titanic          200000000
# 5      6  Star Wars Ep. VII: The Force Awakens          306000000
# 6      7                Avengers: Infinity War          300000000
# 33    34                        Jurassic World          215000000
# ...   ..                                   ...                ...
# 5474  75                       Insomnia Manica             500000
# 5473  74                       Girls Gone Dead             500000
# 5472  73                         Enter Nowhere             500000
# 5471  72                                Drones             500000
# 4068  69                The Kings of Appletown            7000000
#
#       domestic_gross  worldwide_gross
# 0          760507625     2.776345e+09
# 42         659363944     2.208208e+09
# 5          936662225     2.053311e+09
# 6          678815482     2.048134e+09
# 33         652270625     1.648855e+09
# ...              ...              ...
# 5474               0     0.000000e+00
# 5473               0     0.000000e+00
# 5472               0     0.000000e+00
# 5471               0     0.000000e+00
# 4068               0     0.000000e+00
#
# [5782 rows x 5 columns]

# %%
updated_tn_df['Profit from Domestic'] = updated_tn_df['domestic_gross'] - updated_tn_df['production_budget']
updated_tn_df['Profit from Worldwide'] = updated_tn_df['worldwide_gross'] - updated_tn_df['production_budget']

updated_tn_df
# Out:
#       id                                        movie  production_budget  \
# 0      1                                       Avatar          425000000
# 1      2  Pirates of the Caribbean: On Stranger Tides          410600000
# 2      3                                 Dark Phoenix          350000000
# 3      4                      Avengers: Age of Ultron          330600000
# 4      5            Star Wars Ep. VIII: The Last Jedi          317000000
# ...   ..                                          ...                ...
# 5777  78                                       Red 11               7000
# 5778  79                                    Following               6000
# 5779  80                Return to the Land of Wonders               5000
# 5780  81                         A Plague So Pleasant               1400
# 5781  82                            My Date With Drew               1100
#
#       domestic_gross  worldwide_gross  Profit from Domestic  \
# 0          760507625     2.776345e+09             335507625
# 1          241063875     1.045664e+09            -169536125
# 2           42762350     1.497624e+08            -307237650
# 3          459005868     1.403014e+09             128405868
# 4          620181382     1.316722e+09             303181382
# ...              ...              ...                   ...
# 5777               0     0.000000e+00                 -7000
# 5778           48482     2.404950e+05                 42482
# 5779            1338     1.338000e+03                 -3662
# 5780               0     0.000000e+00                 -1400
# 5781          181041     1.810410e+05                179941
#
#       Profit from Worldwide
# 0              2.351345e+09
# 1              6.350639e+08
# 2             -2.002376e+08
# 3              1.072414e+09
# 4              9.997217e+08
# ...                     ...
# 5777          -7.000000e+03
# 5778           2.344950e+05
# 5779          -3.662000e+03
# 5780          -1.400000e+03
# 5781           1.799410e+05
#
# [5782 rows x 7 columns]

# %%
updated_tn_df.sort_values('Profit from Domestic', ascending=False)
# Out:
#       id                                        movie  production_budget  \
# 5      6         Star Wars Ep. VII: The Force Awakens          306000000
# 41    42                                Black Panther          200000000
# 42    43                                      Titanic          200000000
# 3464  65                 Star Wars Ep. IV: A New Hope           11000000
# 33    34                               Jurassic World          215000000
# ...   ..                                          ...                ...
# 31    32                                   Battleship          220000000
# 1      2  Pirates of the Caribbean: On Stranger Tides          410600000
# 12    13                              The Lone Ranger          275000000
# 13    14                                  John Carter          275000000
# 2      3                                 Dark Phoenix          350000000
#
#       domestic_gross  worldwide_gross  Profit from Domestic  \
# 5          936662225     2.053311e+09             630662225
# 41         700059566     1.348258e+09             500059566
# 42         659363944     2.208208e+09             459363944
# 3464       460998007     7.865980e+08             449998007
# 33         652270625     1.648855e+09             437270625
# ...              ...              ...                   ...
# 31          65233400     3.134777e+08            -154766600
# 1          241063875     1.045664e+09            -169536125
# 12          89302115     2.600021e+08            -185697885
# 13          73058679     2.827781e+08            -201941321
# 2           42762350     1.497624e+08            -307237650
#
#       Profit from Worldwide
# 5              1.747311e+09
# 41             1.148258e+09
# 42             2.008208e+09
# 3464           7.755980e+08
# 33             1.433855e+09
# ...                     ...
# 31             9.347772e+07
# 1              6.350639e+08
# 12            -1.499788e+07
# 13             7.778100e+06
# 2             -2.002376e+08
#
# [5782 rows x 7 columns]

# %%
updated_tn_df.sort_values('Profit from Worldwide', ascending=False)
# Out:
#      id                                 movie  production_budget  \
# 0     1                                Avatar          425000000
# 42   43                               Titanic          200000000
# 6     7                Avengers: Infinity War          300000000
# 5     6  Star Wars Ep. VII: The Force Awakens          306000000
# 33   34                        Jurassic World          215000000
# ..   ..                                   ...                ...
# 352  53                        Town & Country          105000000
# 341  42           Men in Black: International          110000000
# 193  94                       Mars Needs Moms          150000000
# 194  95                              Moonfall          150000000
# 2     3                          Dark Phoenix          350000000
#
#      domestic_gross  worldwide_gross  Profit from Domestic  \
# 0         760507625     2.776345e+09             335507625
# 42        659363944     2.208208e+09             459363944
# 6         678815482     2.048134e+09             378815482
# 5         936662225     2.053311e+09             630662225
# 33        652270625     1.648855e+09             437270625
# ..              ...              ...                   ...
# 352         6712451     1.036477e+07             -98287549
# 341         3100000     3.100000e+06            -106900000
# 193        21392758     3.954976e+07            -128607242
# 194               0     0.000000e+00            -150000000
# 2          42762350     1.497624e+08            -307237650
#
#      Profit from Worldwide
# 0             2.351345e+09
# 42            2.008208e+09
# 6             1.748134e+09
# 5             1.747311e+09
# 33            1.433855e+09
# ..                     ...
# 352          -9.463523e+07
# 341          -1.069000e+08
# 193          -1.104502e+08
# 194          -1.500000e+08
# 2            -2.002376e+08
#
# [5782 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
updated_tn_df.plot(x='production_budget', y='Profit from Domestic', kind='scatter')

plt.xlabel('Production Budget')
plt.ylabel('Profit from Domestic')
plt.title('Production Budget v Profit from Domestic')

plt.show()

# %%
updated_tn_df.plot(x='production_budget', y='Profit from Worldwide', kind='scatter')

plt.xlabel('Production Budget')
plt.ylabel('Profit from Worldwide')
plt.title('Production Budget v Profit from Worldwide')

plt.show()

# %%
mean1 = updated_tn_df['Profit from Domestic'].mean()
mean2 = updated_tn_df['Profit from Worldwide'].mean()

# %%
mean1
# Out:
# 10285569.770494638

# %%
mean2
# Out:
# 59899703.80992736

# %%
updated_tn_df.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5782.000000       5.782000e+03    5.782000e+03     5.782000e+03
# mean     50.372363       3.158776e+07    4.187333e+07     9.148746e+07
# std      28.821076       4.181208e+07    6.824060e+07     1.747200e+08
# min       1.000000       1.100000e+03    0.000000e+00     0.000000e+00
# 25%      25.000000       5.000000e+06    1.429534e+06     4.125415e+06
# 50%      50.000000       1.700000e+07    1.722594e+07     2.798445e+07
# 75%      75.000000       4.000000e+07    5.234866e+07     9.764584e+07
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#        Profit from Domestic  Profit from Worldwide
# count          5.782000e+03           5.782000e+03
# mean           1.028557e+07           5.989970e+07
# std            4.992137e+07           1.460889e+08
# min           -3.072376e+08          -2.002376e+08
# 25%           -9.132757e+06          -2.189071e+06
# 50%           -3.487755e+05           8.550286e+06
# 75%            1.778144e+07           6.096850e+07
# max            6.306622e+08           2.351345e+09

# %%
fig, ax = plt.subplots()

ax.bar(['Domestic', 'Worldwide'], [mean1, mean2])

ax.set_title('Mean Profit from Domestic V. Worldwide Gross')
ax.set_ylabel('Profit')

plt.show()
